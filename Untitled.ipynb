# %%
import cv2
import numpy as np
from queue import PriorityQueue
import matplotlib.pyplot as plt
# %matplotlib inline  
# %autosave 120
try:
    import sim
except:
    print ('--------------------------------------------------------------')
    print ('"sim.py" could not be imported. This means very probably that')
    print ('either "vrep.py" or the remoteApi library could not be found.')
    print ('Make sure both are in the same folder as this file,')
    print ('or appropriately adjust the file "sim.py"')
    print ('--------------------------------------------------------------')
    print ('')

import time
from IPython.display import clear_output
from IPython.display import display
import ctypes
# Out:
# Autosaving every 120 seconds

# %%
client_id = sim.simxStart('192.168.1.113', 19997, True, True, 5000, 5)

if client_id != -1:
    print("Connection to CoppeliaSim successful!")
else:
    print("Failed to connect to CoppeliaSim. Check your IP address and port settings.")
# Out:
# Connection to CoppeliaSim successful!

# %%
img = cv2.imread("grid_with_orientation.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# %matplotlib inline
plt.imshow(img)
plt.show()

# %%
def obstacles_grid(img):
    # getting the walls 
    mask_wall = cv2.inRange(img, np.array([230,230,230]),np.array([240,240,240]))
    # getting the rims
    mask_rim = cv2.inRange(img, 0, 0)
    mask_total = cv2.bitwise_or(mask_wall,mask_rim,mask_rim)
    mask_total = cv2.bitwise_not(mask_total)
    return mask_total

# %%
img_obs = obstacles_grid(img)
# %matplotlib inline
plt.imshow(img_obs, cmap="gray")
plt.show()

# %%
def get_front_disk_position (img):
    front_disk_mask = cv2.inRange(img, np.array([100,140,205]), np.array([105,145,210]))
    im2, contours, hierarchy = cv2.findContours(front_disk_mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    #no need for the for loop but it is used to avoid errors
    for c in contours:
        # compute the center of the contour
        M = cv2.moments(c)
        cX = int(M["m10"] / M["m00"])
        cY = int(M["m01"] / M["m00"])
    return np.array([cY,cX])

def get_back_disk_position (img):
    rear_disk_mask = cv2.inRange(img, np.array([75,185,185]), np.array([80,190,190]))    
    im2, contours, hierarchy = cv2.findContours(rear_disk_mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    #no need for the for loop but it is used to avoid errors
    for c in contours:
        # compute the center of the contour
        M = cv2.moments(c)
        cX = int(M["m10"] / M["m00"])
        cY = int(M["m01"] / M["m00"])
    return np.array([cY,cX])
def get_robot_orientation(img):
    front_disk_position = get_front_disk_position (img)
    rear_disk_position =  get_back_disk_position (img)
    orientation = np.arctan2(rear_disk_position[1]-front_disk_position[1] , rear_disk_position[0]-front_disk_position[0])
    return orientation

# %%
orient = get_robot_orientation(img)
print(orient)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 orient = get_robot_orientation(img)
#       2 print(orient)
#
# Cell In[7], line 23, in get_robot_orientation(img)
#      22 def get_robot_orientation(img):
# ---> 23     front_disk_position = get_front_disk_position (img)
#      24     rear_disk_position =  get_back_disk_position (img)
#      25     orientation = np.arctan2(rear_disk_position[1]-front_disk_position[1] , rear_disk_position[0]-front_disk_position[0])
#
# Cell In[7], line 3, in get_front_disk_position(img)
#       1 def get_front_disk_position (img):
#       2     front_disk_mask = cv2.inRange(img, np.array([100,140,205]), np.array([105,145,210]))
# ----> 3     im2, contours, hierarchy = cv2.findContours(front_disk_mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
#       4     #no need for the for loop but it is used to avoid errors
#       5     for c in contours:
#       6         # compute the center of the contour
#
# ValueError: not enough values to unpack (expected 3, got 2)
